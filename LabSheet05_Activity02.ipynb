# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm 
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54  California  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42  California  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df['State'] = df['State'].factorize()[0]

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      0  192261.83
# 1  162597.70       151377.59        443898.53      1  191792.06
# 2  153441.51       101145.55        407934.54      1  191050.39
# 3  144372.41       118671.85        383199.62      0  182901.99
# 4  142107.34        91391.77        366168.42      1  166187.94

# %%
y = df.iloc[:,4]

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
x4 = df.iloc[:,3:4]

# %%
x4.head()
# Out:
#    State
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1

# %%
plt.scatter(x4,y)

# %%
model = LinearRegression() #create a regressor considering x4

# %%
model.fit(x4,y)
# Out:
# LinearRegression()

# %%
X = sm.add_constant(x4)

# %%
model = sm.OLS(y,X).fit() 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.019
# Method:                 Least Squares   F-statistic:                   0.08773
# Date:                Sat, 31 Aug 2024   Prob (F-statistic):              0.768
# Time:                        12:20:44   Log-Likelihood:                -600.61
# No. Observations:                  50   AIC:                             1205.
# Df Residuals:                      48   BIC:                             1209.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.137e+05   8137.342     13.975      0.000    9.74e+04     1.3e+05
# ...

# %% [markdown]
# ### Looking for other independednt varibles

# %%
x3 = df.iloc[:,2:3]

# %%
x3.head()
# Out:
#    Marketing Spend
# 0        471784.10
# 1        443898.53
# 2        407934.54
# 3        383199.62
# 4        366168.42

# %%
plt.scatter(x3,y)

# %%
model = LinearRegression() #create a regressor considering x3
model.fit(x3,y)
# Out:
# LinearRegression()

# %%
X = sm.add_constant(x3)
model = sm.OLS(y,X).fit() 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Sat, 31 Aug 2024   Prob (F-statistic):           4.38e-10
# Time:                        12:21:39   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x2 = df.iloc[:,1:2]
x2.head()
# Out:
#    Administration
# 0       136897.80
# 1       151377.59
# 2       101145.55
# 3       118671.85
# 4        91391.77

# %%
plt.scatter(x2,y)

# %%
model = LinearRegression() #create a regressor considering x2
model.fit(x2,y)
# Out:
# LinearRegression()

# %%
X = sm.add_constant(x2)
model = sm.OLS(y,X).fit() 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Sat, 31 Aug 2024   Prob (F-statistic):              0.162
# Time:                        12:24:47   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
x1 = df.iloc[:,0:1]
x1.head()
# Out:
#    R&D Spend
# 0  165349.20
# 1  162597.70
# 2  153441.51
# 3  144372.41
# 4  142107.34

# %%
plt.scatter(x1,y)

# %%
model = LinearRegression() #create a regressor considering x1
model.fit(x1,y)
# Out:
# LinearRegression()

# %%
X = sm.add_constant(x1)
model = sm.OLS(y,X).fit() 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Sat, 31 Aug 2024   Prob (F-statistic):           3.50e-32
# Time:                        12:28:21   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %% [markdown]
# ### Multiple Lenier Regeression

# %%
x = df[['R&D Spend','Marketing Spend']]

# %%
x.head()
# Out:
#    R&D Spend  Marketing Spend
# 0  165349.20        471784.10
# 1  162597.70        443898.53
# 2  153441.51        407934.54
# 3  144372.41        383199.62
# 4  142107.34        366168.42

# %%
model = LinearRegression() #create a regressor considering x
model.fit(x,y)
# Out:
# LinearRegression()

# %%
X = sm.add_constant(x)
model = sm.OLS(y,X).fit() 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Sat, 31 Aug 2024   Prob (F-statistic):           2.16e-31
# Time:                        12:34:06   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
